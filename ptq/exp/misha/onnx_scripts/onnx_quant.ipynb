# %%
# import torch

# ckpt = torch.load("../../pretrained/G_1000.pth", map_location="cpu")  # или твой путь
# state = ckpt.get("model", ckpt)  # иногда чекпоинт лежит в ключе "model"

# dtypes = {k: v.dtype for k, v in state.items() if torch.is_tensor(v)}
# print(set(dtypes.values()))

# %%
import sys
import logging
from pathlib import Path

# Путь к корню репозитория, внутри которого лежит папка vosk_tts
repo_root = Path("/home/michael/Documents/ITMO/EDLM/phone-tts/vosk-tts")
sys.path.append(str(repo_root))

# теперь импортируем как пакет
from vosk_tts.model import Model
from vosk_tts.synth import Synth

logging.basicConfig(level=logging.INFO)

# Путь к распакованной TTS-модели Vosk (там должны лежать model.onnx, config.json, dictionary, etc.)
model_dir = Path("/home/michael/Documents/ITMO/EDLM/phone-tts/vosk-model-tts-ru-0.9-multi")  # подставь свой

# Загружаем исходный (не квантизованный) onnx
model = Model(model_path=model_dir, model_name=None, lang=None)

synth = Synth(model)
# Out:
# INFO:root:Loading model from /home/michael/Documents/ITMO/EDLM/phone-tts/vosk-model-tts-ru-0.9-multi

# %%
text = "Привет, это тест синтеза речи до квантизации модели."
out_wav = "pre_quant_test.wav"

synth.synth(
    text=text,
    oname=out_wav,
    speaker_id=2,
    noise_level=None,
    speech_rate=1.0,
    duration_noise_level=None,
    scale=None,
)

print("Готово, слушай:", out_wav)
# Out:
# INFO:root:Real-time factor: 0.17 (infer=0.75 sec, audio=4.39 sec)
# Готово, слушай: pre_quant_test.wav

# %% [markdown]
# ### Dinamic Q onnx

# %%
import onnx
from onnxruntime.quantization import quantize_dynamic, QuantType

fp32_model_path = "/home/michael/Documents/ITMO/EDLM/phone-tts/vosk-model-tts-ru-0.9-multi/model.onnx"
int8_model_path = "/home/michael/Documents/ITMO/EDLM/phone-tts/vosk-model-tts-ru-0.9-multi_qd_int8/model.onnx"

model = onnx.load(fp32_model_path)

nodes_to_exclude = [
    node.name
    for node in model.graph.node
    if "time_mlp" in node.name
]

for n in nodes_to_exclude:
    print("  ", n)

extra_options = {
    "DefaultTensorType": onnx.TensorProto.FLOAT,
}

quantize_dynamic(
    model_input=fp32_model_path,
    model_output=int8_model_path,
    weight_type=QuantType.QInt8,
    op_types_to_quantize=["MatMul"],
    nodes_to_exclude=nodes_to_exclude,
    extra_options=extra_options,
)

print("quantized with exclusion, saved to", int8_model_path)
# Out:
# WARNING:root:Please consider to run pre-processing before quantization. Refer to example: https://github.com/microsoft/onnxruntime-inference-examples/blob/main/quantization/image_classification/cpu/ReadMe.md
#    /matcha/decoder/estimator/time_mlp/layer/layer.0/Constant
#    /matcha/decoder/estimator/time_mlp/layer/layer.0/Gemm
#    /matcha/decoder/estimator/time_mlp/layer/layer.1/Sigmoid
#    /matcha/decoder/estimator/time_mlp/layer/layer.1/Mul
#    /matcha/decoder/estimator/time_mlp/layer/layer.2/Gemm
#    /matcha/decoder/estimator/time_mlp/layer/layer.0_1/Constant
#    /matcha/decoder/estimator/time_mlp/layer/layer.0_1/Gemm
#    /matcha/decoder/estimator/time_mlp/layer/layer.1_1/Sigmoid
#    /matcha/decoder/estimator/time_mlp/layer/layer.1_1/Mul
#    /matcha/decoder/estimator/time_mlp/layer/layer.2_1/Gemm
#    /matcha/decoder/estimator/time_mlp/layer/layer.0_2/Constant
#    /matcha/decoder/estimator/time_mlp/layer/layer.0_2/Gemm
#    /matcha/decoder/estimator/time_mlp/layer/layer.1_2/Sigmoid
#    /matcha/decoder/estimator/time_mlp/layer/layer.1_2/Mul
#    /matcha/decoder/estimator/time_mlp/layer/layer.2_2/Gemm
#    /matcha/decoder/estimator/time_mlp/layer/layer.0_3/Constant
#    /matcha/decoder/estimator/time_mlp/layer/layer.0_3/Gemm
#    /matcha/decoder/estimator/time_mlp/layer/layer.1_3/Sigmoid
#    /matcha/decoder/estimator/time_mlp/layer/layer.1_3/Mul
#    /matcha/decoder/estimator/time_mlp/layer/layer.2_3/Gemm
#    /matcha/decoder/estimator/time_mlp/layer/layer.0_4/Constant
#    /matcha/decoder/estimator/time_mlp/layer/layer.0_4/Gemm
#    /matcha/decoder/estimator/time_mlp/layer/layer.1_4/Sigmoid
#    /matcha/decoder/estimator/time_mlp/layer/layer.1_4/Mul
#    /matcha/decoder/estimator/time_mlp/layer/layer.2_4/Gemm
#    /matcha/decoder/estimator/time_mlp/layer/layer.0_5/Constant
#    /matcha/decoder/estimator/time_mlp/layer/layer.0_5/Gemm
#    /matcha/decoder/estimator/time_mlp/layer/layer.1_5/Sigmoid
#    /matcha/decoder/estimator/time_mlp/layer/layer.1_5/Mul
#    /matcha/decoder/estimator/time_mlp/layer/layer.2_5/Gemm
#    /matcha/decoder/estimator/time_mlp/layer/layer.0_6/Constant
#    /matcha/decoder/estimator/time_mlp/layer/layer.0_6/Gemm
#    /matcha/decoder/estimator/time_mlp/layer/layer.1_6/Sigmoid
#    /matcha/decoder/estimator/time_mlp/layer/layer.1_6/Mul
#    /matcha/decoder/estimator/time_mlp/layer/layer.2_6/Gemm
#    /matcha/decoder/estimator/time_mlp/layer/layer.0_7/Constant
#    /matcha/decoder/estimator/time_mlp/layer/layer.0_7/Gemm
#    /matcha/decoder/estimator/time_mlp/layer/layer.1_7/Sigmoid
#    /matcha/decoder/estimator/time_mlp/layer/layer.1_7/Mul
#    /matcha/decoder/estimator/time_mlp/layer/layer.2_7/Gemm
#    /matcha/decoder/estimator/time_mlp/layer/layer.0_8/Constant
#    /matcha/decoder/estimator/time_mlp/layer/layer.0_8/Gemm
#    /matcha/decoder/estimator/time_mlp/layer/layer.1_8/Sigmoid
#    /matcha/decoder/estimator/time_mlp/layer/layer.1_8/Mul
#    /matcha/decoder/estimator/time_mlp/layer/layer.2_8/Gemm
#    /matcha/decoder/estimator/time_mlp/layer/layer.0_9/Constant
#    /matcha/decoder/estimator/time_mlp/layer/layer.0_9/Gemm
#    /matcha/decoder/estimator/time_mlp/layer/layer.1_9/Sigmoid
#    /matcha/decoder/estimator/time_mlp/layer/layer.1_9/Mul
#    /matcha/decoder/estimator/time_mlp/layer/layer.2_9/Gemm
#    /matcha/decoder/estimator/time_mlp/layer/layer.0_10/Constant
#    /matcha/decoder/estimator/time_mlp/layer/layer.0_10/Gemm
#    /matcha/decoder/estimator/time_mlp/layer/layer.1_10/Sigmoid
#    /matcha/decoder/estimator/time_mlp/layer/layer.1_10/Mul
#    /matcha/decoder/estimator/time_mlp/layer/layer.2_10/Gemm
#    /matcha/decoder/estimator/time_mlp/layer/layer.0_11/Constant
#    /matcha/decoder/estimator/time_mlp/layer/layer.0_11/Gemm
#    /matcha/decoder/estimator/time_mlp/layer/layer.1_11/Sigmoid
#    /matcha/decoder/estimator/time_mlp/layer/layer.1_11/Mul
#    /matcha/decoder/estimator/time_mlp/layer/layer.2_11/Gemm
#    /matcha/decoder/estimator/time_mlp/layer/layer.0_12/Constant
#    /matcha/decoder/estimator/time_mlp/layer/layer.0_12/Gemm
#    /matcha/decoder/estimator/time_mlp/layer/layer.1_12/Sigmoid
#    /matcha/decoder/estimator/time_mlp/layer/layer.1_12/Mul
#    /matcha/decoder/estimator/time_mlp/layer/layer.2_12/Gemm
#    /matcha/decoder/estimator/time_mlp/layer/layer.0_13/Constant
#    /matcha/decoder/estimator/time_mlp/layer/layer.0_13/Gemm
#    /matcha/decoder/estimator/time_mlp/layer/layer.1_13/Sigmoid
#    /matcha/decoder/estimator/time_mlp/layer/layer.1_13/Mul
#    /matcha/decoder/estimator/time_mlp/layer/layer.2_13/Gemm
#    /matcha/decoder/estimator/time_mlp/layer/layer.0_14/Constant
#    /matcha/decoder/estimator/time_mlp/layer/layer.0_14/Gemm
#    /matcha/decoder/estimator/time_mlp/layer/layer.1_14/Sigmoid
#    /matcha/decoder/estimator/time_mlp/layer/layer.1_14/Mul
#    /matcha/decoder/estimator/time_mlp/layer/layer.2_14/Gemm
#    /matcha/decoder/estimator/time_mlp/layer/layer.0_15/Constant
#    /matcha/decoder/estimator/time_mlp/layer/layer.0_15/Gemm
#    /matcha/decoder/estimator/time_mlp/layer/layer.1_15/Sigmoid
#    /matcha/decoder/estimator/time_mlp/layer/layer.1_15/Mul
#    /matcha/decoder/estimator/time_mlp/layer/layer.2_15/Gemm
#    /matcha/decoder/estimator/time_mlp/layer/layer.0_16/Constant
#    /matcha/decoder/estimator/time_mlp/layer/layer.0_16/Gemm
#    /matcha/decoder/estimator/time_mlp/layer/layer.1_16/Sigmoid
#    /matcha/decoder/estimator/time_mlp/layer/layer.1_16/Mul
#    /matcha/decoder/estimator/time_mlp/layer/layer.2_16/Gemm
#    /matcha/decoder/estimator/time_mlp/layer/layer.0_17/Constant
#    /matcha/decoder/estimator/time_mlp/layer/layer.0_17/Gemm
#    /matcha/decoder/estimator/time_mlp/layer/layer.1_17/Sigmoid
#    /matcha/decoder/estimator/time_mlp/layer/layer.1_17/Mul
#    /matcha/decoder/estimator/time_mlp/layer/layer.2_17/Gemm
#    /matcha/decoder/estimator/time_mlp/layer/layer.0_18/Constant
#    /matcha/decoder/estimator/time_mlp/layer/layer.0_18/Gemm
#    /matcha/decoder/estimator/time_mlp/layer/layer.1_18/Sigmoid
#    /matcha/decoder/estimator/time_mlp/layer/layer.1_18/Mul
#    /matcha/decoder/estimator/time_mlp/layer/layer.2_18/Gemm
#    /matcha/decoder/estimator/time_mlp/layer/layer.0_19/Constant
#    /matcha/decoder/estimator/time_mlp/layer/layer.0_19/Gemm
#    /matcha/decoder/estimator/time_mlp/layer/layer.1_19/Sigmoid
#    /matcha/decoder/estimator/time_mlp/layer/layer.1_19/Mul
#    /matcha/decoder/estimator/time_mlp/layer/layer.2_19/Gemm
# INFO:root:Quantization parameters for tensor:"/matcha/dur_spk_emb/Gather_output_0" not specified
# INFO:root:Quantization parameters for tensor:"/matcha/encoder/dp_encoder/encoder.0/adaLN_modulation/adaLN_modulation.1/Mul_output_0" not specified
# INFO:root:Ignore MatMul due to non constant B: /[/matcha/encoder/dp_encoder/encoder.0/attn/MatMul]
# INFO:root:Ignore MatMul due to non constant B: /[/matcha/encoder/dp_encoder/encoder.0/attn/MatMul_1]
# INFO:root:Quantization parameters for tensor:"/matcha/encoder/dp_encoder/encoder.1/adaLN_modulation/adaLN_modulation.1/Mul_output_0" not specified
# INFO:root:Ignore MatMul due to non constant B: /[/matcha/encoder/dp_encoder/encoder.1/attn/MatMul]
# INFO:root:Ignore MatMul due to non constant B: /[/matcha/encoder/dp_encoder/encoder.1/attn/MatMul_1]
# INFO:root:Quantization parameters for tensor:"/matcha/encoder/dp_encoder/encoder.2/adaLN_modulation/adaLN_modulation.1/Mul_output_0" not specified
# INFO:root:Ignore MatMul due to non constant B: /[/matcha/encoder/dp_encoder/encoder.2/attn/MatMul]
# INFO:root:Ignore MatMul due to non constant B: /[/matcha/encoder/dp_encoder/encoder.2/attn/MatMul_1]
# INFO:root:Quantization parameters for tensor:"/matcha
output_0" not specified
# INFO:root:Quantization parameters for tensor:"/backbone/convnext.6/norm/LayerNormalization_output_0" not specified
# INFO:root:Quantization parameters for tensor:"/backbone/convnext.6/act/Mul_1_output_0" not specified
# INFO:root:Quantization parameters for tensor:"/backbone/convnext.7/norm/LayerNormalization_output_0" not specified
# INFO:root:Quantization parameters for tensor:"/backbone/convnext.7/act/Mul_1_output_0" not specified
# INFO:root:Quantization parameters for tensor:"/backbone/final_layer_norm/LayerNormalization_output_0" not specified
# quantized with exclusion, saved to /home/michael/Documents/ITMO/EDLM/phone-tts/vosk-model-tts-ru-0.9-multi_qd_int8/model.onnx

# %%
qd_model_dir = Path("/home/michael/Documents/ITMO/EDLM/phone-tts/vosk-model-tts-ru-0.9-multi_qd_int8/") 

qd_model = Model(model_path=qd_model_dir, model_name=None, lang=None)

qd_synth = Synth(qd_model)
# Out:
# INFO:root:Loading model from /home/michael/Documents/ITMO/EDLM/phone-tts/vosk-model-tts-ru-0.9-multi_qd_int8
# ---------------------------------------------------------------------------
# Fail                                      Traceback (most recent call last)
# Cell In[5], line 3
#       1 qd_model_dir = Path("/home/michael/Documents/ITMO/EDLM/phone-tts/vosk-model-tts-ru-0.9-multi_qd_int8/")
# ----> 3 qd_model = Model(model_path=qd_model_dir, model_name=None, lang=None)
#       5 qd_synth = Synth(qd_model)
#
# File ~/Documents/ITMO/EDLM/phone-tts/vosk-tts/vosk_tts/model.py:48, in Model.__init__(self, model_path, model_name, lang)
#      46 #        sess_options.log_severity_level = 0
#      47         logging.info(f"Loading model from {model_path}")
# ---> 48         self.onnx = onnxruntime.InferenceSession(str(model_path / "model.onnx"), sess_options=sess_options, providers=providers)
#      50         self.dic = {}
#      51         probs = {}
#
# File ~/Documents/ITMO/EDLM/phone-tts/.voskvenv/lib/python3.12/site-packages/onnxruntime/capi/onnxruntime_inference_collection.py:485, in InferenceSession.__init__(self, path_or_bytes, sess_options, providers, provider_options, **kwargs)
#     482 disabled_optimizers = kwargs.get("disabled_optimizers")
#     484 try:
# --> 485     self._create_inference_session(providers, provider_options, disabled_optimizers)
#     486 except (ValueError, RuntimeError) as e:
#     487     if self._enable_fallback:
#
# File ~/Documents/ITMO/EDLM/phone-tts/.voskvenv/lib/python3.12/site-packages/onnxruntime/capi/onnxruntime_inference_collection.py:573, in InferenceSession._create_inference_session(self, providers, provider_options, disabled_optimizers)
#     570 self._register_ep_custom_ops(session_options, providers, provider_options, available_providers)
#     572 if self._model_path:
# --> 573     sess = C.InferenceSession(session_options, self._model_path, True, self._read_config_from_model)
#     574 else:
#     575     sess = C.InferenceSession(session_options, self._model_bytes, False, self._read_config_from_model)
#
# Fail: [ONNXRuntimeError] : 1 : FAIL : Load model from /home/michael/Documents/ITMO/EDLM/phone-tts/vosk-model-tts-ru-0.9-multi_qd_int8/model.onnx failed:Node (/matcha/decoder/estimator/time_mlp/layer/layer.0/Gemm_MatMul_quant) Op (MatMulInteger) [ShapeInferenceError] Incompatible dimensions for matrix multiplication

# %%
text = "Привет, это тест синтеза речи после квантизации модели."
out_wav = "post_quant_test.wav"

qd_synth.synth(
    text=text,
    oname=out_wav,
    speaker_id=2,
    noise_level=None,
    speech_rate=1.0,
    duration_noise_level=None,
    scale=None,
)

print(out_wav)
# Out:
# INFO:root:Real-time factor: 0.18 (infer=0.84 sec, audio=4.53 sec)
# post_quant_test.wav

# %%
import onnx

model = onnx.load(fp32_model_path)

for node in model.graph.node:
    if "time_mlp" in node.name:
        print(node.op_type, node.name)
# Out:
# Constant /matcha/decoder/estimator/time_mlp/layer/layer.0/Constant
# Gemm /matcha/decoder/estimator/time_mlp/layer/layer.0/Gemm
# Sigmoid /matcha/decoder/estimator/time_mlp/layer/layer.1/Sigmoid
# Mul /matcha/decoder/estimator/time_mlp/layer/layer.1/Mul
# Gemm /matcha/decoder/estimator/time_mlp/layer/layer.2/Gemm
# Constant /matcha/decoder/estimator/time_mlp/layer/layer.0_1/Constant
# Gemm /matcha/decoder/estimator/time_mlp/layer/layer.0_1/Gemm
# Sigmoid /matcha/decoder/estimator/time_mlp/layer/layer.1_1/Sigmoid
# Mul /matcha/decoder/estimator/time_mlp/layer/layer.1_1/Mul
# Gemm /matcha/decoder/estimator/time_mlp/layer/layer.2_1/Gemm
# Constant /matcha/decoder/estimator/time_mlp/layer/layer.0_2/Constant
# Gemm /matcha/decoder/estimator/time_mlp/layer/layer.0_2/Gemm
# Sigmoid /matcha/decoder/estimator/time_mlp/layer/layer.1_2/Sigmoid
# Mul /matcha/decoder/estimator/time_mlp/layer/layer.1_2/Mul
# Gemm /matcha/decoder/estimator/time_mlp/layer/layer.2_2/Gemm
# Constant /matcha/decoder/estimator/time_mlp/layer/layer.0_3/Constant
# Gemm /matcha/decoder/estimator/time_mlp/layer/layer.0_3/Gemm
# Sigmoid /matcha/decoder/estimator/time_mlp/layer/layer.1_3/Sigmoid
# Mul /matcha/decoder/estimator/time_mlp/layer/layer.1_3/Mul
# Gemm /matcha/decoder/estimator/time_mlp/layer/layer.2_3/Gemm
# Constant /matcha/decoder/estimator/time_mlp/layer/layer.0_4/Constant
# Gemm /matcha/decoder/estimator/time_mlp/layer/layer.0_4/Gemm
# Sigmoid /matcha/decoder/estimator/time_mlp/layer/layer.1_4/Sigmoid
# Mul /matcha/decoder/estimator/time_mlp/layer/layer.1_4/Mul
# Gemm /matcha/decoder/estimator/time_mlp/layer/layer.2_4/Gemm
# Constant /matcha/decoder/estimator/time_mlp/layer/layer.0_5/Constant
# Gemm /matcha/decoder/estimator/time_mlp/layer/layer.0_5/Gemm
# Sigmoid /matcha/decoder/estimator/time_mlp/layer/layer.1_5/Sigmoid
# Mul /matcha/decoder/estimator/time_mlp/layer/layer.1_5/Mul
# Gemm /matcha/decoder/estimator/time_mlp/layer/layer.2_5/Gemm
# Constant /matcha/decoder/estimator/time_mlp/layer/layer.0_6/Constant
# Gemm /matcha/decoder/estimator/time_mlp/layer/layer.0_6/Gemm
# Sigmoid /matcha/decoder/estimator/time_mlp/layer/layer.1_6/Sigmoid
# Mul /matcha/decoder/estimator/time_mlp/layer/layer.1_6/Mul
# Gemm /matcha/decoder/estimator/time_mlp/layer/layer.2_6/Gemm
# Constant /matcha/decoder/estimator/time_mlp/layer/layer.0_7/Constant
# Gemm /matcha/decoder/estimator/time_mlp/layer/layer.0_7/Gemm
# Sigmoid /matcha/decoder/estimator/time_mlp/layer/layer.1_7/Sigmoid
# Mul /matcha/decoder/estimator/time_mlp/layer/layer.1_7/Mul
# Gemm /matcha/decoder/estimator/time_mlp/layer/layer.2_7/Gemm
# Constant /matcha/decoder/estimator/time_mlp/layer/layer.0_8/Constant
# Gemm /matcha/decoder/estimator/time_mlp/layer/layer.0_8/Gemm
# Sigmoid /matcha/decoder/estimator/time_mlp/layer/layer.1_8/Sigmoid
# Mul /matcha/decoder/estimator/time_mlp/layer/layer.1_8/Mul
# Gemm /matcha/decoder/estimator/time_mlp/layer/layer.2_8/Gemm
# Constant /matcha/decoder/estimator/time_mlp/layer/layer.0_9/Constant
# Gemm /matcha/decoder/estimator/time_mlp/layer/layer.0_9/Gemm
# Sigmoid /matcha/decoder/estimator/time_mlp/layer/layer.1_9/Sigmoid
# Mul /matcha/decoder/estimator/time_mlp/layer/layer.1_9/Mul
# Gemm /matcha/decoder/estimator/time_mlp/layer/layer.2_9/Gemm
# Constant /matcha/decoder/estimator/time_mlp/layer/layer.0_10/Constant
# Gemm /matcha/decoder/estimator/time_mlp/layer/layer.0_10/Gemm
# Sigmoid /matcha/decoder/estimator/time_mlp/layer/layer.1_10/Sigmoid
# Mul /matcha/decoder/estimator/time_mlp/layer/layer.1_10/Mul
# Gemm /matcha/decoder/estimator/time_mlp/layer/layer.2_10/Gemm
# Constant /matcha/decoder/estimator/time_mlp/layer/layer.0_11/Constant
# Gemm /matcha/decoder/estimator/time_mlp/layer/layer.0_11/Gemm
# Sigmoid /matcha/decoder/estimator/time_mlp/layer/layer.1_11/Sigmoid
# Mul /matcha/decoder/estimator/time_mlp/layer/layer.1_11/Mul
# Gemm /matcha/decoder/estimator/time_mlp/layer/layer.2_11/Gemm
# Constant /matcha/decoder/estimator/time_mlp/layer/layer.0_12/Constant
# Gemm /matcha/decoder/estimator/time_mlp/layer/layer.0_12/Gemm
# Sigmoid /matcha/decoder/estimator/time_mlp/layer/layer.1_12/Sigmoid
# Mul /matcha/decoder/estimator/time_mlp/layer/layer.1_12/Mul
# Gemm /matcha/decoder/estimator/time_mlp/layer/layer.2_12/Gemm
# Constant /matcha/decoder/estimator/time_mlp/layer/layer.0_13/Constant
# Gemm /matcha/decoder/estimator/time_mlp/layer/layer.0_13/Gemm
# Sigmoid /matcha/decoder/estimator/time_mlp/layer/layer.1_13/Sigmoid
# Mul /matcha/decoder/estimator/time_mlp/layer/layer.1_13/Mul
# Gemm /matcha/decoder/estimator/time_mlp/layer/layer.2_13/Gemm
# Constant /matcha/decoder/estimator/time_mlp/layer/layer.0_14/Constant
# Gemm /matcha/decoder/estimator/time_mlp/layer/layer.0_14/Gemm
# Sigmoid /matcha/decoder/estimator/time_mlp/layer/layer.1_14/Sigmoid
# Mul /matcha/decoder/estimator/time_mlp/layer/layer.1_14/Mul
# Gemm /matcha/decoder/estimator/time_mlp/layer/layer.2_14/Gemm
# Constant /matcha/decoder/estimator/time_mlp/layer/layer.0_15/Constant
# Gemm /matcha/decoder/estimator/time_mlp/layer/layer.0_15/Gemm
# Sigmoid /matcha/decoder/estimator/time_mlp/layer/layer.1_15/Sigmoid
# Mul /matcha/decoder/estimator/time_mlp/layer/layer.1_15/Mul
# Gemm /matcha/decoder/estimator/time_mlp/layer/layer.2_15/Gemm
# Constant /matcha/decoder/estimator/time_mlp/layer/layer.0_16/Constant
# Gemm /matcha/decoder/estimator/time_mlp/layer/layer.0_16/Gemm
# Sigmoid /matcha/decoder/estimator/time_mlp/layer/layer.1_16/Sigmoid
# Mul /matcha/decoder/estimator/time_mlp/layer/layer.1_16/Mul
# Gemm /matcha/decoder/estimator/time_mlp/layer/layer.2_16/Gemm
# Constant /matcha/decoder/estimator/time_mlp/layer/layer.0_17/Constant
# Gemm /matcha/decoder/estimator/time_mlp/layer/layer.0_17/Gemm
# Sigmoid /matcha/decoder/estimator/time_mlp/layer/layer.1_17/Sigmoid
# Mul /matcha/decoder/estimator/time_mlp/layer/layer.1_17/Mul
# Gemm /matcha/decoder/estimator/time_mlp/layer/layer.2_17/Gemm
# Constant /matcha/decoder/estimator/time_mlp/layer/layer.0_18/Constant
# Gemm /matcha/decoder/estimator/time_mlp/layer/layer.0_18/Gemm
# Sigmoid /matcha/decoder/estimator/time_mlp/layer/layer.1_18/Sigmoid
# Mul /matcha/decoder/estimator/time_mlp/layer/layer.1_18/Mul
# Gemm /matcha/decoder/estimator/time_mlp/layer/layer.2_18/Gemm
# Constant /matcha/decoder/estimator/time_mlp/layer/layer.0_19/Constant
# Gemm /matcha/decoder/estimator/time_mlp/layer/layer.0_19/Gemm
# Sigmoid /matcha/decoder/estimator/time_mlp/layer/layer.1_19/Sigmoid
# Mul /matcha/decoder/estimator/time_mlp/layer/layer.1_19/Mul
# Gemm /matcha/decoder/estimator/time_mlp/layer/layer.2_19/Gemm
